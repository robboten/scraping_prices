# %%
import requests


url = "https://qknhp8tc3y-dsn.algolia.net/1/indexes/produits_en/query"

headers = {
    "Accept": 'application/json',
    'Referer': 'https://www.instant-gaming.com/',
    'User-Agent':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36",
    'content-type': 'application/x-www-form-urlencoded'
}

params = {
    "x-algolia-agent": "Algolia for vanilla JavaScript (lite) 3.24.7",
    "x-algolia-api-key": "4813969db52fc22897f8b84bac1299ad",
    "x-algolia-application-id": "QKNHP8TC3Y",
    "filter":"(sites:ig) AND (region:Worldwide OR region:SE OR region:Europe)"
}

payload={
    "query": "Hitman 3",
    "distinct": True,
    "hitsPerPage": 60,
}

response = requests.request("POST", url, headers=headers, json=payload, params=params)
response.json()
# Out:
# {'hits': [{'lang': 'en',
#    'name': 'Hitman 3',
#    'prod_id': '6851',
#    'seo_name': 'hitman-3-pc-game-epic-games-europe',
#    'small_name': 'Hitman 3',
#    'type': 'Epic Games',
#    'region': 'Europe',
#    'is_dlc': '0',
#    'preorder': '0',
#    'brand': 'Io-Interactive A/S',
#    'is_draft': '0',
#    'is_delivered': '1',
#    'retail_currency': 'EUR',
#    'other_platforms_prod_id': '8010,12619',
#    'similar_prod_id': '',
#    'promo': '0',
#    'discount': 72,
#    'currency_prices': {'EUR': 16.69,
#     'USD': 16.69,
#     'GBP': 16.69,
#     'DKK': 16.69,
#     'CHF': 16.69,
#     'CAD': 16.69,
#     'RSD': 16.69,
#     'CZK': 16.69,
#     'AUD': 16.69,
#     'SEK': 16.69,
#     'PLN': 16.69,
#     'NOK': 16.69,
#     'AED': 16.69,
#     'BRL': 16.69},
#    'sites': ['ig'],
#    'sites_prices': {'ig': 16.69},
#    'platforms': ['1'],
#    'price': 16.69,
#    'retail': '59.99',
#    'category': ['Single-player', 'Action', 'Adventure'],
#    'search_tags': ['Action',
#     'Stealth',
#     'VR',
#     'Assassin',
#     'Adventure',
#     'Sandbox',
#     'Shooter',
#     'Third-Person Shooter',
#     'Violent',
#     'Third Person',
#     'Cinematic',
#     'Realistic',
#     'Funny',
#     'Gore',
#     'Puzzle',
#     'Capitalism',
#     'Immersive Sim',
#     'Open World',
#     'Single-player',
#     'Action',
#     'Adventure'],
#    'avail_date': 1642636800,
#    'vpn_countries': None,
#    'exclude_from_search': '0',
#    'langs': ['cn', 'de', 'en', 'es', 'fr', 'it', 'jp', 'ru'],
#    'manual_search_tags': None,
#    'developer_id': '941',
#    'publisher_id': '941',
#    'is_free_to_play': '0',
#    'updated_at': 1657198147,
#    'has_video_preview': '1',
#    'video_preview_updated_at': '1659126963',
#    'is_prepaid': '0',
#    'developer_name': 'Io-Interactive A/S',
#    'publisher_name': 'Io-Interactive A/S',
#    'can_display_video_preview': '1',
#    'platform': 'Epic Games',
#    'reviews_avg': 90,
#    'cat_ids': ['47', '1', '4'],
#    'lcat': 'H',
#    'objectID': '6851',
#    '_highlightResult': {'name': {'value': '<em>Hitman</em> <em>3</em>',
#      'matchLevel': 'full',
#      'fullyHighlighted': True,
#      'matchedWords': ['hitman', '3']},
#     'small_name': {'value': '<em>Hitman</em> <em>3</em>',
#      'matchLevel': 'full',
#      'fullyHighlighted': True,
#      'matchedWords': ['hitman', '3']},
#     'search_tags': [{'value': 'Action',
#       'matchLevel': 'none',
#       'matchedWords': []},
#      {'value': 'Stealth', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'VR', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Assassin', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Adventure', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Sandbox', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Shooter', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Third-Person Shooter',
#       'matchLevel': 'none',
#       'matchedWords': []},
#      {'value': 'Violent', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Third Person', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Cinematic', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Realistic', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Funny', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Gore', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Puzzle', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Capitalism', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Immersive Sim', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Open World', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Single-player', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Action', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Adventure', 'matchLevel': 'none', 'matchedWords': []}],
#     'developer_name': {'value': 'Io-Interactive A/S',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'publisher_name': {'value': 'Io-Interactive A/S',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'lang': 'en',
#    'name': 'Hitman 3',
#    'prod_id': '12619',
#    'seo_name': 'hitman-3-pc-game-steam',
#    'small_name': 'Hitman 3',
#    'type': 'Steam',
#    'region': 'Worldwide',
#    'is_dlc': '0',
#    'preorder': '0',
#    'brand': 'Io-Interactive A/S',
#    'is_draft': '0',
#    'is_delivered': '1',
#    'retail_currency': 'EUR',
#    'other_platforms_prod_id': '6851,8010',
#    'similar_prod_id': '',
#    'promo': '0',
#    'discount': 57,
#    'currency_prices': {'EUR': 25.75,
#     'PLN': 23.26,
#     'USD': 25.75,
#     'GBP': 25.75,
#     'DKK': 25.75,
#     'CHF': 25.75,
#     'CAD': 25.75,
#     'RSD': 25.75,
#     'CZK': 25.75,
#     'AUD': 25.75,
#     'SEK': 25.75,
#     'NOK': 25.75,
#     'AED': 25.75,
#     'BRL': 25.75},
#    'sites': ['ig'],
#    'sites_prices': {'ig': 25.75},
#    'platforms': ['1'],
#    'price': 25.75,
#    'retail': '59.99',
#    'category': ['Single-player', 'Action', 'Adventure'],
#    'search_tags': ['Action',
#     'Stealth',
#     'VR',
#     'Assassin',
#     'Adventure',
#     'Sandbox',
#     'Shooter',
#     'Third-Person Shooter',
#     'Violent',
#     'Third Person',
#     'Cinematic',
#     'Realistic',
#     'Funny',
#     'Gore',
#     'Puzzle',
#     'Capitalism',
#     'Immersive Sim',
#     'Open World',
#     'Single-player',
#     'Action',
#     'Adventure'],
#    'avail_date': 1642636800,
#    'vpn_countries': None,
#    'exclude_from_search': '0',
#    'langs': ['cn', 'de', 'en', 'es', 'fr', 'it', 'jp', 'ru'],
#    'manual_search_tags': None,
#    'developer_id': '941',
#    'publisher_id': '941',
#    'is_free_to_play': '0',
#    'updated_at': 1659079811,
#    'has_video_preview': '1',
#    'video_preview_updated_at': '1659126963',
#    'is_prepaid': '0',
#    'developer_name': 'Io-Interactive A/S',
#    'publisher_name': 'Io-Interactive A/S',
#    'can_display_video_preview': '1',
#    'platform': 'Steam',
#    'reviews_avg': 90,
#    'cat_ids': ['47', '1', '4'],
#    'lcat': 'H',
#    'objectID': '12619',
#    '_highlightResult': {'name': {'value': '<em>Hitman</em> <em>3</em>',
#      'matchLevel': 'full',
#      'fullyHighlighted': True,
#      'matchedWords': ['hitman', '3']},
#     'small_name': {'value': '<em>Hitman</em> <em>3</em>',
#      'matchLevel': 'full',
#      'fullyHighlighted': True,
#      'matchedWords': ['hitman', '3']},
#     'search_tags': [{'value': 'Action',
#       'matchLevel': 'none',
#       'matchedWords': []},
#      {'value': 'Stealth', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'VR', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Assassin', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Adventure', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Sandbox', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Shooter', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Third-Person Shooter',
#       'matchLevel': 'none',
#       'matchedWords': []},
#      {'value': 'Violent', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Third Person', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Cinematic', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Realistic', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Funny', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Gore', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Puzzle', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Capitalism', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Immersive Sim', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Open World', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Single-player', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Action', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Adventure', 'matchLevel': 'none', 'matchedWords': []}],
#     'developer_name': {'value': 'Io-Interactive A/S',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'publisher_name': {'value': 'Io-Interactive A/S',
#      'matchLevel': 'none',
#      'matchedWords': []}}},
#   {'lang': 'en',
#    'name': 'Hitman 3 (Xbox ONE / Xbox Series X|S)',
#    'prod_id': '8010',
#    'seo_name': 'hitman-3-xbox-one-xbox-series-x-s-xbox-one-xbox-series-x-s-game-microsoft-store',
#    'small_name': 'Hitman 3 (Xbox ONE / Xbox Series X|S)',
#    'type': 'Microsoft Store',
#    'region': 'Worldwide',
#    'is_dlc': '0',
#    'preorder': '0',
#    'brand': 'Io-Interactive A/S',
#    'is_draft': '0',
#    'is_delivered': '1',
#    'retail_currency': 'EUR',
#    'other_platforms_prod_id': '6851,12619',
#    'similar_prod_id': '',
#    'promo': '0',
#    'discount': 8,
#    'currency_prices': {'EUR': 55.26,
#     'PLN': 56.46,
#     'USD': 55.26,
#     'GBP': 55.26,
#     'DKK': 55.26,
#     'CHF': 55.26,
#     'CAD': 55.26,
#     'RSD': 55.26,
#     'CZK': 55.26,
#     'AUD': 55.26,
#     'SEK': 55.26,
#     'NOK': 55.26,
#     'AED': 55.26,
#     'BRL': 55.26},
#    'sites': ['ig'],
#    'sites_prices': {'ig': 55.26},
#    'platforms': ['11', '12'],
#    'price': 55.26,
#    'retail': '59.99',
#    'category': ['Single-player', 'Action', 'Adventure'],
#    'search_tags': ['Action',
#     'Stealth',
#     'VR',
#     'Assassin',
#     'Adventure',
#     'Sandbox',
#     'Shooter',
#     'Third-Person Shooter',
#     'Violent',
#     'Third Person',
#     'Cinematic',
#     'Realistic',
#     'Funny',
#     'Gore',
#     'Puzzle',
#     'Capitalism',
#     'Immersive Sim',
#     'Open World',
#     'Single-player',
#     'Action',
#     'Adventure'],
#    'avail_date': 1642636800,
#    'vpn_countries': None,
#    'exclude_from_search': '0',
#    'langs': ['cn', 'de', 'en', 'es', 'fr', 'it', 'jp', 'ru'],
#    'manual_search_tags': None,
#    'developer_id': '941',
#    'publisher_id': '941',
#    'is_free_to_play': '0',
#    'updated_at': 1657198095,
#    'has_video_preview': '1',
#    'video_preview_updated_at': '1659126963',
#    'is_prepaid': '0',
#    'developer_name': 'Io-Interactive A/S',
#    'publisher_name': 'Io-Interactive A/S',
#    'can_display_video_preview': '1',
#    'platform': 'Xbox Series X|S',
#    'reviews_avg': 90,
#    'cat_ids': ['47', '1', '4'],
#    'lcat': 'H',
#    'objectID': '8010',
#    '_highlightResult': {'name': {'value': '<em>Hitman</em> <em>3</em> (Xbox ONE / Xbox Series X|S)',
#      'matchLevel': 'full',
#      'fullyHighlighted': False,
#      'matchedWords': ['hitman', '3']},
#     'small_name': {'value': '<em>Hitman</em> <em>3</em> (Xbox ONE / Xbox Series X|S)',
#      'matchLevel': 'full',
#      'fullyHighlighted': False,
#      'matchedWords': ['hitman', '3']},
#     'search_tags': [{'value': 'Action',
#       'matchLevel': 'none',
#       'matchedWords': []},
#      {'value': 'Stealth', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'VR', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Assassin', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Adventure', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Sandbox', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Shooter', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Third-Person Shooter',
#       'matchLevel': 'none',
#       'matchedWords': []},
#      {'value': 'Violent', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Third Person', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Cinematic', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Realistic', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Funny', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Gore', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Puzzle', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Capitalism', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Immersive Sim', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Open World', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Single-player', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Action', 'matchLevel': 'none', 'matchedWords': []},
#      {'value': 'Adventure', 'matchLevel': 'none', 'matchedWords': []}],
#     'developer_name': {'value': 'Io-Interactive A/S',
#      'matchLevel': 'none',
#      'matchedWords': []},
#     'publisher_name': {'value': 'Io-Interactive A/S',
#      'matchLevel': 'none',
#      'matchedWords': []}}}],
#  'nbHits': 3,
#  'page': 0,
#  'nbPages': 1,
#  'hitsPerPage': 60,
#  'exhaustiveNbHits': True,
#  'exhaustiveTypo': True,
#  'exhaustive': {'nbHits': True, 'typo': True},
#  'query': 'Hitman 3',
#  'params': 'query=Hitman+3&distinct=true&hitsPerPage=60',
#  'processingTimeMS': 1}

# %%
response.json()['hits'][0]
# Out:
# {'lang': 'en',
#  'name': 'Hitman 3',
#  'prod_id': '6851',
#  'seo_name': 'hitman-3-pc-game-epic-games-europe',
#  'small_name': 'Hitman 3',
#  'type': 'Epic Games',
#  'region': 'Europe',
#  'is_dlc': '0',
#  'preorder': '0',
#  'brand': 'Io-Interactive A/S',
#  'is_draft': '0',
#  'is_delivered': '1',
#  'retail_currency': 'EUR',
#  'other_platforms_prod_id': '8010,12619',
#  'similar_prod_id': '',
#  'promo': '0',
#  'discount': 72,
#  'currency_prices': {'EUR': 16.69,
#   'USD': 16.69,
#   'GBP': 16.69,
#   'DKK': 16.69,
#   'CHF': 16.69,
#   'CAD': 16.69,
#   'RSD': 16.69,
#   'CZK': 16.69,
#   'AUD': 16.69,
#   'SEK': 16.69,
#   'PLN': 16.69,
#   'NOK': 16.69,
#   'AED': 16.69,
#   'BRL': 16.69},
#  'sites': ['ig'],
#  'sites_prices': {'ig': 16.69},
#  'platforms': ['1'],
#  'price': 16.69,
#  'retail': '59.99',
#  'category': ['Single-player', 'Action', 'Adventure'],
#  'search_tags': ['Action',
#   'Stealth',
#   'VR',
#   'Assassin',
#   'Adventure',
#   'Sandbox',
#   'Shooter',
#   'Third-Person Shooter',
#   'Violent',
#   'Third Person',
#   'Cinematic',
#   'Realistic',
#   'Funny',
#   'Gore',
#   'Puzzle',
#   'Capitalism',
#   'Immersive Sim',
#   'Open World',
#   'Single-player',
#   'Action',
#   'Adventure'],
#  'avail_date': 1642636800,
#  'vpn_countries': None,
#  'exclude_from_search': '0',
#  'langs': ['cn', 'de', 'en', 'es', 'fr', 'it', 'jp', 'ru'],
#  'manual_search_tags': None,
#  'developer_id': '941',
#  'publisher_id': '941',
#  'is_free_to_play': '0',
#  'updated_at': 1657198147,
#  'has_video_preview': '1',
#  'video_preview_updated_at': '1659126963',
#  'is_prepaid': '0',
#  'developer_name': 'Io-Interactive A/S',
#  'publisher_name': 'Io-Interactive A/S',
#  'can_display_video_preview': '1',
#  'platform': 'Epic Games',
#  'reviews_avg': 90,
#  'cat_ids': ['47', '1', '4'],
#  'lcat': 'H',
#  'objectID': '6851',
#  '_highlightResult': {'name': {'value': '<em>Hitman</em> <em>3</em>',
#    'matchLevel': 'full',
#    'fullyHighlighted': True,
#    'matchedWords': ['hitman', '3']},
#   'small_name': {'value': '<em>Hitman</em> <em>3</em>',
#    'matchLevel': 'full',
#    'fullyHighlighted': True,
#    'matchedWords': ['hitman', '3']},
#   'search_tags': [{'value': 'Action',
#     'matchLevel': 'none',
#     'matchedWords': []},
#    {'value': 'Stealth', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'VR', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'Assassin', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'Adventure', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'Sandbox', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'Shooter', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'Third-Person Shooter', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'Violent', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'Third Person', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'Cinematic', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'Realistic', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'Funny', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'Gore', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'Puzzle', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'Capitalism', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'Immersive Sim', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'Open World', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'Single-player', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'Action', 'matchLevel': 'none', 'matchedWords': []},
#    {'value': 'Adventure', 'matchLevel': 'none', 'matchedWords': []}],
#   'developer_name': {'value': 'Io-Interactive A/S',
#    'matchLevel': 'none',
#    'matchedWords': []},
#   'publisher_name': {'value': 'Io-Interactive A/S',
#    'matchLevel': 'none',
#    'matchedWords': []}}}

# %%
import pandas as pd

# %%
df_hitman=pd.json_normalize(response.json(),record_path=['hits'])
#df_hitman.iloc[:1,10:]
df_hitman
# Out:
#   lang                                   name prod_id  \
# 0   en                               Hitman 3    6851
# 1   en                               Hitman 3   12619
# 2   en  Hitman 3 (Xbox ONE / Xbox Series X|S)    8010
#
#                                             seo_name  \
# 0                 hitman-3-pc-game-epic-games-europe
# 1                             hitman-3-pc-game-steam
# 2  hitman-3-xbox-one-xbox-series-x-s-xbox-one-xbo...
#
#                               small_name             type     region is_dlc  \
# 0                               Hitman 3       Epic Games     Europe      0
# 1                               Hitman 3            Steam  Worldwide      0
# 2  Hitman 3 (Xbox ONE / Xbox Series X|S)  Microsoft Store  Worldwide      0
#
#   preorder               brand  ... _highlightResult.small_name.matchLevel  \
# 0        0  Io-Interactive A/S  ...                                   full
# 1        0  Io-Interactive A/S  ...                                   full
# 2        0  Io-Interactive A/S  ...                                   full
#
#   _highlightResult.small_name.fullyHighlighted  \
# 0                                         True
# 1                                         True
# 2                                        False
#
#   _highlightResult.small_name.matchedWords  \
# 0                              [hitman, 3]
# 1                              [hitman, 3]
# 2                              [hitman, 3]
#
#                         _highlightResult.search_tags  \
# 0  [{'value': 'Action', 'matchLevel': 'none', 'ma...
# 1  [{'value': 'Action', 'matchLevel': 'none', 'ma...
# 2  [{'value': 'Action', 'matchLevel': 'none', 'ma...
#
#   _highlightResult.developer_name.value  \
# 0                    Io-Interactive A/S
# 1                    Io-Interactive A/S
# 2                    Io-Interactive A/S
#
#   _highlightResult.developer_name.matchLevel  \
# 0                                       none
# 1                                       none
# 2                                       none
#
#    _highlightResult.developer_name.matchedWords  \
# 0                                            []
# 1                                            []
# 2                                            []
#
#   _highlightResult.publisher_name.value  \
# 0                    Io-Interactive A/S
# 1                    Io-Interactive A/S
# 2                    Io-Interactive A/S
#
#   _highlightResult.publisher_name.matchLevel  \
# 0                                       none
# 1                                       none
# 2                                       none
#
#    _highlightResult.publisher_name.matchedWords
# 0                                            []
# 1                                            []
# 2                                            []
#
# [3 rows x 73 columns]

# %% [markdown]
# df_hitman.dtypes

# %% [markdown]
# df_hitman.keys()

# %%
floats=[
    'price',
    'retail'
]



df['Percent Growth'].apply(lambda x: x.replace('%', '')).astype('float') / 100
df["Active"] = np.where(df["Active"] == "Y", True, False)

df = pd.concat([pd.DataFrame(json_dict), 
                json_normalize(json_dict['nested_array_to_expand'])], 
                axis=1).drop('nested_array_to_expand', 1)

# %%
columns_drop=[
    '_highlightResult',
    'currency_prices',
    'sites_prices',
    'developer_name',
    'publisher_name'
]

is_bools=[
    'is_dlc',
    'preorder',
    'is_draft',
    'is_delivered',
    'exclude_from_search',
    'is_free_to_play',
    'has_video_preview',
    'is_prepaid',
    'can_display_video_preview',
    'promo'
]
def str2bool(val): 
    if val == "1":
        return True
    else: 
        return False

for item in is_bools:
    df_hitman[item]= df_hitman[item].apply(str2bool)

df_hitman
# Out:
#   lang                                   name prod_id  \
# 0   en                               Hitman 3    6851
# 1   en                               Hitman 3   12619
# 2   en  Hitman 3 (Xbox ONE / Xbox Series X|S)    8010
#
#                                             seo_name  \
# 0                 hitman-3-pc-game-epic-games-europe
# 1                             hitman-3-pc-game-steam
# 2  hitman-3-xbox-one-xbox-series-x-s-xbox-one-xbo...
#
#                               small_name             type     region  is_dlc  \
# 0                               Hitman 3       Epic Games     Europe   False
# 1                               Hitman 3            Steam  Worldwide   False
# 2  Hitman 3 (Xbox ONE / Xbox Series X|S)  Microsoft Store  Worldwide   False
#
#    preorder               brand  ...  _highlightResult.small_name.matchLevel  \
# 0     False  Io-Interactive A/S  ...                                    full
# 1     False  Io-Interactive A/S  ...                                    full
# 2     False  Io-Interactive A/S  ...                                    full
#
#    _highlightResult.small_name.fullyHighlighted  \
# 0                                          True
# 1                                          True
# 2                                         False
#
#   _highlightResult.small_name.matchedWords  \
# 0                              [hitman, 3]
# 1                              [hitman, 3]
# 2                              [hitman, 3]
#
#                         _highlightResult.search_tags  \
# 0  [{'value': 'Action', 'matchLevel': 'none', 'ma...
# 1  [{'value': 'Action', 'matchLevel': 'none', 'ma...
# 2  [{'value': 'Action', 'matchLevel': 'none', 'ma...
#
#   _highlightResult.developer_name.value  \
# 0                    Io-Interactive A/S
# 1                    Io-Interactive A/S
# 2                    Io-Interactive A/S
#
#    _highlightResult.developer_name.matchLevel  \
# 0                                        none
# 1                                        none
# 2                                        none
#
#    _highlightResult.developer_name.matchedWords  \
# 0                                            []
# 1                                            []
# 2                                            []
#
#   _highlightResult.publisher_name.value  \
# 0                    Io-Interactive A/S
# 1                    Io-Interactive A/S
# 2                    Io-Interactive A/S
#
#   _highlightResult.publisher_name.matchLevel  \
# 0                                       none
# 1                                       none
# 2                                       none
#
#    _highlightResult.publisher_name.matchedWords
# 0                                            []
# 1                                            []
# 2                                            []
#
# [3 rows x 73 columns]

# %%
for item in columns_drop:
    df_hitman.drop(item,inplace=True,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [57], line 2
#       1 for item in columns_drop:
# ----> 2     df_hitman.drop(item,inplace=True,axis=1)
#
# File ~/.local/share/virtualenvs/scraping_prices-xhRARkWB/lib/python3.9/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/scraping_prices-xhRARkWB/lib/python3.9/site-packages/pandas/core/frame.py:5391, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5243 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5244 def drop(  # type: ignore[override]
#    5245     self,
#    (...)
#    5252     errors: IgnoreRaise = "raise",
#    5253 ) -> DataFrame | None:
#    5254     """
#    5255     Drop specified labels from rows or columns.
#    5256
#    (...)
#    5389             weight  1.0     0.8
#    5390     """
# -> 5391     return super().drop(
#    5392         labels=labels,
#    5393         axis=axis,
#    5394         index=index,
#    5395         columns=columns,
#    5396         level=level,
#    5397         inplace=inplace,
#    5398         errors=errors,
#    5399     )
#
# File ~/.local/share/virtualenvs/scraping_prices-xhRARkWB/lib/python3.9/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/scraping_prices-xhRARkWB/lib/python3.9/site-packages/pandas/core/generic.py:4510, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4508 for axis, labels in axes.items():
#    4509     if labels is not None:
# -> 4510         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4512 if inplace:
#    4513     self._update_inplace(obj)
#
# File ~/.local/share/virtualenvs/scraping_prices-xhRARkWB/lib/python3.9/site-packages/pandas/core/generic.py:4551, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4549         new_axis = axis.drop(labels, level=level, errors=errors)
#    4550     else:
# -> 4551         new_axis = axis.drop(labels, errors=errors)
#    4552     indexer = axis.get_indexer(new_axis)
#    4554 # Case for non-unique axis
#    4555 else:
#
# File ~/.local/share/virtualenvs/scraping_prices-xhRARkWB/lib/python3.9/site-packages/pandas/core/indexes/base.py:6972, in Index.drop(self, labels, errors)
#    6970 if mask.any():
#    6971     if errors != "ignore":
# -> 6972         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6973     indexer = indexer[~mask]
#    6974 return self.delete(indexer)
#
# KeyError: "['_highlightResult', 'currency_prices', 'sites_prices'] not found in axis"

# %%
df_hitman['has_video_preview']
# Out:
# 0    True
# 1    True
# 2    True
# Name: has_video_preview, dtype: bool

# %%
df_hitman['is_dlc'].astype('int').astype('bool')
# Out:
# 0    False
# 1    False
# 2    False
# Name: is_dlc, dtype: bool

# %%
df_hitman.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 73 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   lang                                          3 non-null      object
#  1   name                                          3 non-null      object
#  2   prod_id                                       3 non-null      object
#  3   seo_name                                      3 non-null      object
#  4   small_name                                    3 non-null      object
#  5   type                                          3 non-null      object
#  6   region                                        3 non-null      object
#  7   is_dlc                                        3 non-null      object
#  8   preorder                                      3 non-null      object
#  9   brand                                         3 non-null      object
#  10  is_draft                                      3 non-null      object
#  11  is_delivered                                  3 non-null      object
#  12  retail_currency                               3 non-null      object
#  13  other_platforms_prod_id                       3 non-null      object
#  14  similar_prod_id                               3 non-null      object
#  15  promo                                         3 non-null      object
#  16  discount                                      3 non-null      int64
#  17  sites                                         3 non-null      object
#  18  platforms                                     3 non-null      object
#  19  price                                         3 non-null      float64
#  20  retail                                        3 non-null      object
#  21  category                                      3 non-null      object
#  22  search_tags                                   3 non-null      object
#  23  avail_date                                    3 non-null      int64
#  24  vpn_countries                                 0 non-null      object
#  25  exclude_from_search                           3 non-null      object
#  26  langs                                         3 non-null      object
#  27  manual_search_tags                            0 non-null      object
#  28  developer_id                                  3 non-null      object
#  29  publisher_id                                  3 non-null      object
#  30  is_free_to_play                               3 non-null      object
#  31  updated_at                                    3 non-null      int64
#  32  has_video_preview                             3 non-null      object
#  33  video_preview_updated_at                      3 non-null      object
#  34  is_prepaid                                    3 non-null      object
#  35  developer_name                                3 non-null      object
#  36  publisher_name                                3 non-null      object
#  37  can_display_video_preview                     3 non-null      object
#  38  platform                                      3 non-null      object
#  39  reviews_avg                                   3 non-null      int64
#  40  cat_ids                                       3 non-null      object
#  41  lcat                                          3 non-null      object
#  42  objectID                                      3 non-null      object
#  43  currency_prices.EUR                           3 non-null      float64
#  44  currency_prices.USD                           3 non-null      float64
#  45  currency_prices.GBP                           3 non-null      float64
#  46  currency_prices.DKK                           3 non-null      float64
#  47  currency_prices.CHF                           3 non-null      float64
#  48  currency_prices.CAD                           3 non-null      float64
#  49  currency_prices.RSD                           3 non-null      float64
#  50  currency_prices.CZK                           3 non-null      float64
#  51  currency_prices.AUD                           3 non-null      float64
#  52  currency_prices.SEK                           3 non-null      float64
#  53  currency_prices.PLN                           3 non-null      float64
#  54  currency_prices.NOK                           3 non-null      float64
#  55  currency_prices.AED                           3 non-null      float64
#  56  currency_prices.BRL                           3 non-null      float64
#  57  sites_prices.ig                               3 non-null      float64
#  58  _highlightResult.name.value                   3 non-null      object
#  59  _highlightResult.name.matchLevel              3 non-null      object
#  60  _highlightResult.name.fullyHighlighted        3 non-null      bool
#  61  _highlightResult.name.matchedWords            3 non-null      object
#  62  _highlightResult.small_name.value             3 non-null      object
#  63  _highlightResult.small_name.matchLevel        3 non-null      object
#  64  _highlightResult.small_name.fullyHighlighted  3 non-null      bool
#  65  _highlightResult.small_name.matchedWords      3 non-null      object
#  66  _highlightResult.search_tags                  3 non-null      object
#  67  _highlightResult.developer_name.value         3 non-null      object
#  68  _highlightResult.developer_name.matchLevel    3 non-null      object
#  69  _highlightResult.developer_name.matchedWords  3 non-null      object
#  70  _highlightResult.publisher_name.value         3 non-null      object
#  71  _highlightResult.publisher_name.matchLevel    3 non-null      object
#  72  _highlightResult.publisher_name.matchedWords  3 non-null      object
# dtypes: bool(2), float64(16), int64(4), object(51)
# memory usage: 1.8+ KB

# %%
#import sqlite3 as db
import sqlalchemy as dba

# %%
engine = dba.create_engine('sqlite:///gameprices.db', echo=True)
sqlite_connection = engine.connect()

# %% [markdown]
# conn=db.connect('gameprices.db')
# c=conn.cursor()

# %%
#c.execute("CREATE TABLE employees (empid INTEGER PRIMARY KEY, firstname NVARCHAR(20), lastname NVARCHAR(20))")

# %%
#c.execute("INSERT INTO employees VALUES (12986,'Michael','Scott')")
#c.execute("INSERT INTO employees VALUES (12987,'Dwight','Schrute')")

# %% [markdown]
# new_employees = [
#     (12994, 'Jim', 'Halpert'),
#     (12988, 'Pam', 'Beesly'),
#     (12989, 'Andy', 'Bernard'),
#     (12990, 'Kevin', 'Malone'),
#     (12991, 'Toby', 'Flenderson'),
#     (12992, 'Angela', 'Martin'),
#     (12993, 'Stanley', 'Hudson')]
#
# c.executemany('INSERT INTO employees VALUES (?, ?, ?)', new_employees)

# %% [markdown]
# c.execute("SELECT * FROM employees")
# print(c.fetchall())

# %% [markdown]
# con = db.connect('gameprices.db')
# df_employees = pd.read_sql_query('select * from employees', con)
# df_employees

# %% [markdown]
# df_new = df_employees[:-1]

# %% [markdown]
# df_new.to_sql("employees", con, if_exists="replace")

# %%
df_hitman.iloc[:,17:]
# Out:
#                                      currency_prices sites   sites_prices  \
# 0  {'EUR': 16.69, 'USD': 16.69, 'GBP': 16.69, 'DK...  [ig]  {'ig': 16.69}
# 1  {'EUR': 25.75, 'PLN': 23.26, 'USD': 25.75, 'GB...  [ig]  {'ig': 25.75}
# 2  {'EUR': 55.26, 'PLN': 56.46, 'USD': 55.26, 'GB...  [ig]  {'ig': 55.26}
#
#   platforms  price retail                            category  \
# 0       [1]  16.69  59.99  [Single-player, Action, Adventure]
# 1       [1]  25.75  59.99  [Single-player, Action, Adventure]
# 2  [11, 12]  55.26  59.99  [Single-player, Action, Adventure]
#
#                                          search_tags  avail_date  \
# 0  [Action, Stealth, VR, Assassin, Adventure, San...  1642636800
# 1  [Action, Stealth, VR, Assassin, Adventure, San...  1642636800
# 2  [Action, Stealth, VR, Assassin, Adventure, San...  1642636800
#
#   vpn_countries  ... is_prepaid      developer_name      publisher_name  \
# 0          None  ...          0  Io-Interactive A/S  Io-Interactive A/S
# 1          None  ...          0  Io-Interactive A/S  Io-Interactive A/S
# 2          None  ...          0  Io-Interactive A/S  Io-Interactive A/S
#
#   can_display_video_preview         platform reviews_avg     cat_ids lcat  \
# 0                         1       Epic Games          90  [47, 1, 4]    H
# 1                         1            Steam          90  [47, 1, 4]    H
# 2                         1  Xbox Series X|S          90  [47, 1, 4]    H
#
#   objectID                                   _highlightResult
# 0     6851  {'name': {'value': '<em>Hitman</em> <em>3</em>...
# 1    12619  {'name': {'value': '<em>Hitman</em> <em>3</em>...
# 2     8010  {'name': {'value': '<em>Hitman</em> <em>3</em>...
#
# [3 rows x 29 columns]

# %%
df_hitman.to_csv('steam_data',index=False)

# %%
#con = db.connect('gameprices.db')
dfh.to_sql('steam_games', sqlite_connection, if_exists="replace", index=False,dtype={"currency_prices": dba.types.JSON,"sites_prices":dba.types.ARRAY(dba.types.INT())})
# Out:
# 2022-10-18 17:43:14,293 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("steam_games")
# 2022-10-18 17:43:14,294 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-10-18 17:43:14,295 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("steam_games")
# 2022-10-18 17:43:14,295 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-10-18 17:43:14,297 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2022-10-18 17:43:14,297 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-10-18 17:43:14,299 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("steam_games")
# 2022-10-18 17:43:14,299 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-10-18 17:43:14,301 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2022-10-18 17:43:14,302 INFO sqlalchemy.engine.Engine [raw sql] ('steam_games',)
# 2022-10-18 17:43:14,303 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("steam_games")
# 2022-10-18 17:43:14,304 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-10-18 17:43:14,304 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("steam_games")
# 2022-10-18 17:43:14,304 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-10-18 17:43:14,305 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2022-10-18 17:43:14,305 INFO sqlalchemy.engine.Engine [raw sql] ('steam_games',)
# 2022-10-18 17:43:14,307 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("steam_games")
# 2022-10-18 17:43:14,307 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-10-18 17:43:14,308 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("steam_games")
# 2022-10-18 17:43:14,308 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-10-18 17:43:14,310 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("steam_games")
# 2022-10-18 17:43:14,310 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-10-18 17:43:14,311 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("steam_games")
# 2022-10-18 17:43:14,311 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-10-18 17:43:14,312 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2022-10-18 17:43:14,312 INFO sqlalchemy.engine.Engine [raw sql] ('steam_games',)
# 2022-10-18 17:43:14,314 INFO sqlalchemy.engine.Engine
# DROP TABLE steam_games
# 2022-10-18 17:43:14,314 INFO sqlalchemy.engine.Engine [no key 0.00043s] ()
# 2022-10-18 17:43:14,327 INFO sqlalchemy.engine.Engine COMMIT
# 2022-10-18 17:43:14,330 INFO sqlalchemy.engine.Engine
# CREATE TABLE steam_games (
# 	lang TEXT,
# 	name TEXT,
# 	prod_id TEXT,
# 	seo_name TEXT,
# 	small_name TEXT,
# 	type TEXT,
# 	region TEXT,
# 	is_dlc TEXT,
# 	preorder TEXT,
# 	brand TEXT,
# 	is_draft TEXT,
# 	is_delivered TEXT,
# 	retail_currency TEXT,
# 	other_platforms_prod_id TEXT,
# 	similar_prod_id TEXT,
# 	promo TEXT,
# 	discount BIGINT,
# 	currency_prices JSON,
# 	sites TEXT,
# 	sites_prices TEXT,
# 	platforms TEXT,
# 	price FLOAT,
# 	retail TEXT,
# 	category TEXT,
# 	search_tags TEXT,
# 	avail_date BIGINT,
# 	vpn_countries TEXT,
# 	exclude_from_search TEXT,
# 	langs TEXT,
# 	manual_search_tags TEXT,
# 	developer_id TEXT,
# 	publisher_id TEXT,
# 	is_free_to_play TEXT,
# 	updated_at BIGINT,
# 	has_video_preview TEXT,
# 	video_preview_updated_at TEXT,
# 	is_prepaid TEXT,
# 	developer_name TEXT,
# 	publisher_name TEXT,
# 	can_display_video_preview TEXT,
# 	platform TEXT,
# 	reviews_avg BIGINT,
# 	cat_ids TEXT,
# 	lcat TEXT,
# 	"objectID" TEXT,
# 	"_highlightResult" TEXT
# )
#
#
# 2022-10-18 17:43:14,331 INFO sqlalchemy.engine.Engine [no key 0.00083s] ()
# 2022-10-18 17:43:14,346 INFO sqlalchemy.engine.Engine COMMIT
# 2022-10-18 17:43:14,349 INFO sqlalchemy.engine.Engine INSERT INTO steam_games (lang, name, prod_id, seo_name, small_name, type, region, is_dlc, preorder, brand, is_draft, is_delivered, retail_currency, other_platforms_prod_id, similar_prod_id, promo, discount, currency_prices, sites, sites_prices, platforms, price, retail, category, search_tags, avail_date, vpn_countries, exclude_from_search, langs, manual_search_tags, developer_id, publisher_id, is_free_to_play, updated_at, has_video_preview, video_preview_updated_at, is_prepaid, developer_name, publisher_name, can_display_video_preview, platform, reviews_avg, cat_ids, lcat, "objectID", "_highlightResult") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2022-10-18 17:43:14,350 INFO sqlalchemy.engine.Engine [generated in 0.00127s] (('en', 'Hitman 3', '6851', 'hitman-3-pc-game-epic-games-europe', 'Hitman 3', 'Epic Games', 'Europe', '0', '0', 'Io-Interactive A/S', '0', '1', 'EUR', '8010,12619', '', '0', 72, '{"EUR": 16.69, "USD": 16.69, "GBP": 16.69, "DKK": 16.69, "CHF": 16.69, "CAD": 16.69, "RSD": 16.69, "CZK": 16.69, "AUD": 16.69, "SEK": 16.69, "PLN": 16.69, "NOK": 16.69, "AED": 16.69, "BRL": 16.69}', "['ig']", {'ig': 16.69}, "['1']", 16.69, '59.99', ['Single-player', 'Action', 'Adventure'], ['Action', 'Stealth', 'VR', 'Assassin', 'Adventure', 'Sandbox', 'Shooter', 'Third-Person Shooter', 'Violent', 'Third Person', 'Cinematic', 'Realistic', 'Funny', 'Gore', 'Puzzle', 'Capitalism', 'Immersive Sim', 'Open World', 'Single-player', 'Action', 'Adventure'], 1642636800, None, '0', ['cn', 'de', 'en', 'es', 'fr', 'it', 'jp', 'ru'], None, '941', '941', '0', 1657198147, '1', '1659126963', '0', 'Io-Interactive A/S', 'Io-Interactive A/S', '1', 'Epic Games', 90, ['47', '1', '4'], 'H', '6851', {'name': {'value': '<em>Hitman</em> <em>3</em>', 'matchLevel': 'full', 'fullyHighlighted': True, 'matchedWords': ['hitman', '3']}, 'small_name': {'val ... (1545 characters truncated) ... eractive A/S', 'matchLevel': 'none', 'matchedWords': []}, 'publisher_name': {'value': 'Io-Interactive A/S', 'matchLevel': 'none', 'matchedWords': []}}), ('en', 'Hitman 3', '12619', 'hitman-3-pc-game-steam', 'Hitman 3', 'Steam', 'Worldwide', '0', '0', 'Io-Interactive A/S', '0', '1', 'EUR', '6851,8010', '', '0', 57, '{"EUR": 25.75, "PLN": 23.26, "USD": 25.75, "GBP": 25.75, "DKK": 25.75, "CHF": 25.75, "CAD": 25.75, "RSD": 25.75, "CZK": 25.75, "AUD": 25.75, "SEK": 25.75, "NOK": 25.75, "AED": 25.75, "BRL": 25.75}', "['ig']", {'ig': 25.75}, "['1']", 25.75, '59.99', ['Single-player', 'Action', 'Adventure'], ['Action', 'Stealth', 'VR', 'Assassin', 'Adventure', 'Sandbox', 'Shooter', 'Third-Person Shooter', 'Violent', 'Third Person', 'Cinematic', 'Realistic', 'Funny', 'Gore', 'Puzzle', 'Capitalism', 'Immersive Sim', 'Open World', 'Single-player', 'Action', 'Adventure'], 1642636800, None, '0', ['cn', 'de', 'en', 'es', 'fr', 'it', 'jp', 'ru'], None, '941', '941', '0', 1659079811, '1', '1659126963', '0', 'Io-Interactive A/S', 'Io-Interactive A/S', '1', 'Steam', 90, ['47', '1', '4'], 'H', '12619', {'name': {'value': '<em>Hitman</em> <em>3</em>', 'matchLevel': 'full', 'fullyHighlighted': True, 'matchedWords': ['hitman', '3']}, 'small_name': {'val ... (1545 characters truncated) ... eractive A/S', 'matchLevel': 'none', 'matchedWords': []}, 'publisher_name': {'value': 'Io-Interactive A/S', 'matchLevel': 'none', 'matchedWords': []}}), ('en', 'Hitman 3 (Xbox ONE / Xbox Series X|S)', '8010', 'hitman-3-xbox-one-xbox-series-x-s-xbox-one-xbox-series-x-s-game-microsoft-store', 'Hitman 3 (Xbox ONE / Xbox Series X|S)', 'Microsoft Store', 'Worldwide', '0', '0', 'Io-Interactive A/S', '0', '1', 'EUR', '6851,12619', '', '0', 8, '{"EUR": 55.26, "PLN": 56.46, "USD": 55.26, "GBP": 55.26, "DKK": 55.26, "CHF": 55.26, "CAD": 55.26, "RSD": 55.26, "CZK": 55.26, "AUD": 55.26, "SEK": 55.26, "NOK": 55.26, "AED": 55.26, "BRL": 55.26}', "['ig']", {'ig': 55.26}, "['11', '12']", 55.26, '59.99', ['Single-player', 'Action', 'Adventure'], ['Action', 'Stealth', 'VR', 'Assassin', 'Adventure', 'Sandbox', 'Shooter', 'Third-Person Shooter', 'Violent', 'Third Person', 'Cinematic', 'Realistic', 'Funny', 'Gore', 'Puzzle', 'Capitalism', 'Immersive Sim', 'Open World', 'Single-player', 'Action', 'Adventure'], 1642636800, None, '0', ['cn', 'de', 'en', 'es', 'fr', 'it', 'jp', 'ru'], None, '941', '941', '0', 1657198095, '1', '1659126963', '0', 'Io-Interactive A/S', 'Io-Interactive A/S', '1', 'Xbox Series X|S', 90, ['47', '1', '4'], 'H', '8010', {'name': {'value': '<em>Hitman</em> <em>3</em> (Xbox ONE / Xbox Series X|S)', 'matchLevel': 'full', 'fullyHighlighted': False, 'matchedWords': ['hitma ... (1605 characters truncated) ... eractive A/S', 'matchLevel': 'none', 'matchedWords': ...
# 2022-10-18 17:43:14,351 INFO sqlalchemy.engine.Engine ROLLBACK
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# File c:\Users\robbo\.virtualenvs\scraping_prices-iCStyPHz\lib\site-packages\sqlalchemy\engine\base.py:1880, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1879     if not evt_handled:
# -> 1880         self.dialect.do_executemany(
#    1881             cursor, statement, parameters, context
#    1882         )
#    1883 elif not parameters and context.no_parameters:
#
# File c:\Users\robbo\.virtualenvs\scraping_prices-iCStyPHz\lib\site-packages\sqlalchemy\engine\default.py:733, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     732 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 733     cursor.executemany(statement, parameters)
#
# InterfaceError: Error binding parameter 19 - probably unsupported type.
#
# The above exception was the direct cause of the following exception:
#
# InterfaceError                            Traceback (most recent call last)
# Cell In [25], line 2
#       1 #con = db.connect('gameprices.db')
# ----> 2 dfh.to_sql('steam_games', sqlite_connection, if_exists="replace", index=False,dtype={"currency_prices": dba.types.JSON,"":dba.types.ARRAY(dba.types.INT())})
#
# File c:\Users\robbo\.virtualenvs\scraping_prices-iCStyPHz\lib\site-packages\pandas\core\generic.py:2986, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2829 """
#    2830 Write records stored in a DataFrame to a SQL database.
#    2831
#    (...)
#    2982 [(1,), (None,), (2,)]
#    2983 """  # noqa:E501
#    2984 from pandas.io import sql
# -> 2986 return sql.to_sql(
#    2987     self,
#    2988     name,
#    2989     con,
#    2990     schema=schema,
#    2991     if_exists=if_exists,
#    2992     index=index,
#    2993     index_label=index_label,
#    2994     chunksize=chunksize,
#    2995     dtype=dtype,
#    2996     method=method,
#    2997 )
#
# File c:\Users\robbo\.virtualenvs\scraping_prices-iCStyPHz\lib\site-packages\pandas\io\sql.py:696, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     691 elif not isinstance(frame, DataFrame):
#     692     raise NotImplementedError(
#     693         "'frame' argument should be either a Series or a DataFrame"
#     694     )
# --> 696 return pandas_sql.to_sql(
#     697     frame,
#     698     name,
#     699     if_exists=if_exists,
#     700     index=index,
#     701     index_label=index_label,
#     702     schema=schema,
#     703     chunksize=chunksize,
#     704     dtype=dtype,
#     705     method=method,
#     706     engine=engine,
#     707     **engine_kwargs,
#     708 )
#
# File c:\Users\robbo\.virtualenvs\scraping_prices-iCStyPHz\lib\site-packages\pandas\io\sql.py:1739, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1727 sql_engine = get_engine(engine)
#    1729 table = self.prep_table(
#    1730     frame=frame,
#    1731     name=name,
#    (...)
#    1736     dtype=dtype,
#    1737 )
# -> 1739 total_inserted = sql_engine.insert_records(
#    1740     table=table,
#    1741     con=self.connectable,
#    1742     frame=frame,
#    1743     name=name,
#    1744     index=index,
#    1745     schema=schema,
#    1746     chunksize=chunksize,
#    1747     method=method,
#    1748     **engine_kwargs,
#    1749 )
#    1751 self.check_case_sensitive(name=name, schema=schema)
#    1752 return total_inserted
#
# File c:\Users\robbo\.virtualenvs\scraping_prices-iCStyPHz\lib\site-packages\pandas\io\sql.py:1336, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1334     raise ValueError("inf cannot be used with MySQL") from err
#    1335 else:
# -> 1336     raise err
#
# File c:\Users\robbo\.virtualenvs\scraping_prices-iCStyPHz\lib\site-packages\pandas\io\sql.py:1326, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1323 from sqlalchemy import exc
#    1325 try:
# -> 1326     return table.insert(chunksize=chunksize, method=method)
#    1327 except exc.SQLAlchemyError as err:
#    1328     # GH34431
#    1329     # https://stackoverflow.com/a/67358288/6067848
#    1330     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1331     )|inf can not be used with MySQL"""
#
# File c:\Users\robbo\.virtualenvs\scraping_prices-iCStyPHz\lib\site-packages\pandas\io\sql.py:947, in SQLTable.insert(self, chunksize, method)
#     944     break
#     946 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# --> 947 num_inserted = exec_insert(conn, keys, chunk_iter)
#     948 # GH 46891
#     949 if is_integer(num_inserted):
#
# File c:\Users\robbo\.virtualenvs\scraping_prices-iCStyPHz\lib\site-packages\pandas\io\sql.py:854, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     842 """
#     843 Execute SQL statement inserting data
#     844
#    (...)
#     851    Each item contains a list of values to be inserted
#     852 """
#     853 data = [dict(zip(keys, row)) for row in data_iter]
# --> 854 result = conn.execute(self.table.insert(), data)
#     855 return result.rowcount
#
# File c:\Users\robbo\.virtualenvs\scraping_prices-iCStyPHz\lib\site-packages\sqlalchemy\engine\base.py:1380, in Connection.execute(self, statement, *multiparams, **params)
#    1376     util.raise_(
#    1377         exc.ObjectNotExecutableError(statement), replace_context=err
#    1378     )
#    1379 else:
# -> 1380     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File c:\Users\robbo\.virtualenvs\scraping_prices-iCStyPHz\lib\site-packages\sqlalchemy\sql\elements.py:333, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     329 def _execute_on_connection(
#     330     self, connection, multiparams, params, execution_options, _force=False
#     331 ):
#     332     if _force or self.supports_execution:
# --> 333         return connection._execute_clauseelement(
#     334             self, multiparams, params, execution_options
#     335         )
#     336     else:
#     337         raise exc.ObjectNotExecutableError(self)
#
# File c:\Users\robbo\.virtualenvs\scraping_prices-iCStyPHz\lib\site-packages\sqlalchemy\engine\base.py:1572, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1560 compiled_cache = execution_options.get(
#    1561     "compiled_cache", self.engine._compiled_cache
#    1562 )
#    1564 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1565     dialect=dialect,
#    1566     compiled_cache=compiled_cache,
#    (...)
#    1570     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1571 )
# -> 1572 ret = self._execute_context(
#    1573     dialect,
#    1574     dialect.execution_ctx_cls._init_compiled,
#    1575     compiled_sql,
#    1576     distilled_params,
#    1577     execution_options,
#    1578     compiled_sql,
#    1579     distilled_params,
#    1580     elem,
#    1581     extracted_params,
#    1582     cache_hit=cache_hit,
#    1583 )
#    1584 if has_events:
#    1585     self.dispatch.after_execute(
#    1586         self,
#    1587         elem,
#    (...)
#    1591         ret,
#    1592     )
#
# File c:\Users\robbo\.virtualenvs\scraping_prices-iCStyPHz\lib\site-packages\sqlalchemy\engine\base.py:1943, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1940             branched.close()
#    1942 except BaseException as e:
# -> 1943     self._handle_dbapi_exception(
#    1944         e, statement, parameters, cursor, context
#    1945     )
#    1947 return result
#
# File c:\Users\robbo\.virtualenvs\scraping_prices-iCStyPHz\lib\site-packages\sqlalchemy\engine\base.py:2124, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2122     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2123 elif should_wrap:
# -> 2124     util.raise_(
#    2125         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2126     )
#    2127 else:
#    2128     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File c:\Users\robbo\.virtualenvs\scraping_prices-iCStyPHz\lib\site-packages\sqlalchemy\util\compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File c:\Users\robbo\.virtualenvs\scraping_prices-iCStyPHz\lib\site-packages\sqlalchemy\engine\base.py:1880, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1878                 break
#    1879     if not evt_handled:
# -> 1880         self.dialect.do_executemany(
#    1881             cursor, statement, parameters, context
#    1882         )
#    1883 elif not parameters and context.no_parameters:
#    1884     if self.dialect._has_events:
#
# File c:\Users\robbo\.virtualenvs\scraping_prices-iCStyPHz\lib\site-packages\sqlalchemy\engine\default.py:733, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     732 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 733     cursor.executemany(statement, parameters)
#
# InterfaceError: (sqlite3.InterfaceError) Error binding parameter 19 - probably unsupported type.
# [SQL: INSERT INTO steam_games (lang, name, prod_id, seo_name, small_name, type, region, is_dlc, preorder, brand, is_draft, is_delivered, retail_currency, other_platforms_prod_id, similar_prod_id, promo, discount, currency_prices, sites, sites_prices, platforms, price, retail, category, search_tags, avail_date, vpn_countries, exclude_from_search, langs, manual_search_tags, developer_id, publisher_id, is_free_to_play, updated_at, has_video_preview, video_preview_updated_at, is_prepaid, developer_name, publisher_name, can_display_video_preview, platform, reviews_avg, cat_ids, lcat, "objectID", "_highlightResult") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: (('en', 'Hitman 3', '6851', 'hitman-3-pc-game-epic-games-europe', 'Hitman 3', 'Epic Games', 'Europe', '0', '0', 'Io-Interactive A/S', '0', '1', 'EUR', '8010,12619', '', '0', 72, '{"EUR": 16.69, "USD": 16.69, "GBP": 16.69, "DKK": 16.69, "CHF": 16.69, "CAD": 16.69, "RSD": 16.69, "CZK": 16.69, "AUD": 16.69, "SEK": 16.69, "PLN": 16.69, "NOK": 16.69, "AED": 16.69, "BRL": 16.69}', "['ig']", {'ig': 16.69}, "['1']", 16.69, '59.99', ['Single-player', 'Action', 'Adventure'], ['Action', 'Stealth', 'VR', 'Assassin', 'Adventure', 'Sandbox', 'Shooter', 'Third-Person Shooter', 'Violent', 'Third Person', 'Cinematic', 'Realistic', 'Funny', 'Gore', 'Puzzle', 'Capitalism', 'Immersive Sim', 'Open World', 'Single-player', 'Action', 'Adventure'], 1642636800, None, '0', ['cn', 'de', 'en', 'es', 'fr', 'it', 'jp', 'ru'], None, '941', '941', '0', 1657198147, '1', '1659126963', '0', 'Io-Interactive A/S', 'Io-Interactive A/S', '1', 'Epic Games', 90, ['47', '1', '4'], 'H', '6851', {'name': {'value': '<em>Hitman</em> <em>3</em>', 'matchLevel': 'full', 'fullyHighlighted': True, 'matchedWords': ['hitman', '3']}, 'small_name': {'val ... (1545 characters truncated) ... eractive A/S', 'matchLevel': 'none', 'matchedWords': []}, 'publisher_name': {'value': 'Io-Interactive A/S', 'matchLevel': 'none', 'matchedWords': []}}), ('en', 'Hitman 3', '12619', 'hitman-3-pc-game-steam', 'Hitman 3', 'Steam', 'Worldwide', '0', '0', 'Io-Interactive A/S', '0', '1', 'EUR', '6851,8010', '', '0', 57, '{"EUR": 25.75, "PLN": 23.26, "USD": 25.75, "GBP": 25.75, "DKK": 25.75, "CHF": 25.75, "CAD": 25.75, "RSD": 25.75, "CZK": 25.75, "AUD": 25.75, "SEK": 25.75, "NOK": 25.75, "AED": 25.75, "BRL": 25.75}', "['ig']", {'ig': 25.75}, "['1']", 25.75, '59.99', ['Single-player', 'Action', 'Adventure'], ['Action', 'Stealth', 'VR', 'Assassin', 'Adventure', 'Sandbox', 'Shooter', 'Third-Person Shooter', 'Violent', 'Third Person', 'Cinematic', 'Realistic', 'Funny', 'Gore', 'Puzzle', 'Capitalism', 'Immersive Sim', 'Open World', 'Single-player', 'Action', 'Adventure'], 1642636800, None, '0', ['cn', 'de', 'en', 'es', 'fr', 'it', 'jp', 'ru'], None, '941', '941', '0', 1659079811, '1', '1659126963', '0', 'Io-Interactive A/S', 'Io-Interactive A/S', '1', 'Steam', 90, ['47', '1', '4'], 'H', '12619', {'name': {'value': '<em>Hitman</em> <em>3</em>', 'matchLevel': 'full', 'fullyHighlighted': True, 'matchedWords': ['hitman', '3']}, 'small_name': {'val ... (1545 characters truncated) ... eractive A/S', 'matchLevel': 'none', 'matchedWords': []}, 'publisher_name': {'value': 'Io-Interactive A/S', 'matchLevel': 'none', 'matchedWords': []}}), ('en', 'Hitman 3 (Xbox ONE / Xbox Series X|S)', '8010', 'hitman-3-xbox-one-xbox-series-x-s-xbox-one-xbox-series-x-s-game-microsoft-store', 'Hitman 3 (Xbox ONE / Xbox Series X|S)', 'Microsoft Store', 'Worldwide', '0', '0', 'Io-Interactive A/S', '0', '1', 'EUR', '6851,12619', '', '0', 8, '{"EUR": 55.26, "PLN": 56.46, "USD": 55.26, "GBP": 55.26, "DKK": 55.26, "CHF": 55.26, "CAD": 55.26, "RSD": 55.26, "CZK": 55.26, "AUD": 55.26, "SEK": 55.26, "NOK": 55.26, "AED": 55.26, "BRL": 55.26}', "['ig']", {'ig': 55.26}, "['11', '12']", 55.26, '59.99', ['Single-player', 'Action', 'Adventure'], ['Action', 'Stealth', 'VR', 'Assassin', 'Adventure', 'Sandbox', 'Shooter', 'Third-Person Shooter', 'Violent', 'Third Person', 'Cinematic', 'Realistic', 'Funny', 'Gore', 'Puzzle', 'Capitalism', 'Immersive Sim', 'Open World', 'Single-player', 'Action', 'Adventure'], 1642636800, None, '0', ['cn', 'de', 'en', 'es', 'fr', 'it', 'jp', 'ru'], None, '941', '941', '0', 1657198095, '1', '1659126963', '0', 'Io-Interactive A/S', 'Io-Interactive A/S', '1', 'Xbox Series X|S', 90, ['47', '1', '4'], 'H', '8010', {'name': {'value': '<em>Hitman</em> <em>3</em> (Xbox ONE / Xbox Series X|S)', 'matchLevel': 'full', 'fullyHighlighted': False, 'matchedWords': ['hitma ... (1605 characters truncated) ... eractive A/S', 'matchLevel': 'none', 'matchedWords': []}, 'publisher_name': {'value': 'Io-Interactive A/S', 'matchLev ...
# (Background on this error at: https://sqlalche.me/e/14/rvf5)

# %%
conn.commit()

# %%
sqlite_connection.close()

# %%
c.close
conn.close()
